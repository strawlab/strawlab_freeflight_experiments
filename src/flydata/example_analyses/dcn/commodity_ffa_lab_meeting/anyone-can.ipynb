# %% [markdown]
# ## An example of freeflight data analysis

# %%
# Some imports of basic python stuff
from time import time
import cPickle as pickle
import os.path as op

# Plotting stuff (time allowing)
import seaborn as sb
import matplotlib.pyplot as plt

# High-level API to help retrieving and processing freeflight data
from flydata.strawlab.trajectories import FreeflightTrajectory
from flydata.example_analyses.dcn.dcn_data import load_lisa_dcn_trajectories, dcn_conflict_select_columns, \
    DCN_COMPLETED_EXPERIMENTS, load_lisa_dcn_experiments, DCN_POST_CENTER, DCN_CONFLICT_CONDITION, \
    DCN_ROTATION_CONDITION
from flydata.features.common import Length, Mean, Skew, Std, Kurtosis, compute_features
from flydata.features.correlations import RollingCorr
from flydata.features.post import PostAttention, TimeInCircularRegion
from flydata.strawlab.contracts import NoMissingValuesContract, NoHolesContract, AllNumericContract, check_contracts
from flydata.strawlab.files import FreeflightAnalysisFiles
from flydata.strawlab.transformers import MissingImputer, ColumnsSelector, NumericEnforcer, RowsWithMissingRemover, \
    ShortLongRemover
    
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# A (local) directory in which we will store data and results; copy in a USB and put it in your wallet...
CACHE_DIR = op.join(op.expanduser('~'), 'data-analysis', 'strawlab', 'dcns', '20140909', 'original')
CACHE_DIR
# Out:
# '/home/santi/data-analysis/strawlab/dcns/20140909/original'

# %%
# What time-series are we going to keep from the combined trajectories?
INTERESTING_SERIES = dcn_conflict_select_columns()
INTERESTING_SERIES
# Out:
# ['ax',
#  'ay',
#  'az',
#  'dtheta',
#  'omega',
#  'radius',
#  'ratio',
#  'rcurve',
#  'rotation_rate',
#  'theta',
#  'trg_x',
#  'trg_y',
#  'trg_z',
#  'velocity',
#  'vx',
#  'vy',
#  'vz',
#  'x',
#  'y',
#  'z']

# %%
# These are the stimuli series (we will need to impute missing values for these columns)
STIMULI_SERIES = ('rotation_rate', 'trg_x', 'trg_y', 'trg_z', 'ratio')

# %%
# These are transformations we will apply to the data
TRANSFORMERS = (
    # Get only long enough series (4 seconds or more...)
    # ShortLongRemover(min_length_frames=400),
    # Filter-out uninteresting series
    ColumnsSelector(series_to_keep=INTERESTING_SERIES),
    # Make all series numeric
    NumericEnforcer(),
    # Fill missing values in stimuli data (make sure it makes sense for all the series)
    MissingImputer(columns=STIMULI_SERIES, faster_if_available=True),
    # Filter-out trajectories with missing values in the responses anywhere (which should not happen anymore)
    RowsWithMissingRemover(log_removed=True)
)
# Out:
# WARNING: numba is not installed, slow filling will make you impatient

# %%
# These are contracts for the data in our trajectories
CONTRACTS = (
    NoMissingValuesContract(columns=INTERESTING_SERIES),  # No missing values, please
    NoHolesContract(),                                    # No holes in time series, please
    AllNumericContract(),                                 # No "object" columns, please
)

# %%
# Let's compute "stimulus following" series and others
SOME_SERIES_EXTRACTORS = (
    # Is the fly going towards the post? (0.2 seconds to assess fly direction)
    PostAttention(ws=20),
    # Is the fly going towards the post? (0.2 seconds to assess fly direction)
    PostAttention(postx='trg_x', posty='trg_y', ws=20),
    # Rolling correlation between turn-rate and stimulus rotation rate (window size 20)
    RollingCorr(response='dtheta', stimulus='rotation_rate', ws=20)
)

# %%
# These are the parameters of the function I showed you, so I can copy-paste here its body
uuids=DCN_COMPLETED_EXPERIMENTS
cache_dir=CACHE_DIR
data_name='munged_data'
mirror_locally=False
transformers=TRANSFORMERS
contracts=CONTRACTS
series_extractors=SOME_SERIES_EXTRACTORS
recompute=False

# %%
# We will store the computed trajectories here...
cache_file = op.join(cache_dir, '%s.pkl' % data_name)
cache_file
# Out:
# '/home/santi/data-analysis/strawlab/dcns/20140909/original/munged_data.pkl'

# %%
# Provenance: store what we do to the data
provenance = [FreeflightAnalysisFiles(op.join(CACHE_DIR, uuids[0])).configuration().id()]  # All same...
provenance_file = op.join(cache_dir, '%s-provenance.log' % data_name)
provenance_file
# Out:
# '/home/santi/data-analysis/strawlab/dcns/20140909/original/munged_data-provenance.log'

# %%
# Do not redo work...
if not op.isfile(cache_file) or recompute:

    # Load the trajectories from the local cache
    print '\tLoading data from original combine results...'
    start = time()
    trajs = load_lisa_dcn_trajectories(uuids=uuids, cache_root_dir=CACHE_DIR)  # WARNING missing provenance!
    print '\tLoaded %d trajectories, it took %.2f seconds' % (len(trajs), time() - start)

    # Apply transformers
    print '\tTransforming the trajectories data-set...'
    start = time()
    for transformer in transformers:
        print '\t\t' + transformer.configuration().id()
        trajs = transformer.fit_transform(trajs)
        provenance.append(transformer.configuration().id())
    print '\tTransformations took %.2f seconds, there are %d trajectories left' % (time() - start, len(trajs))

    # Check contracts
    print '\tChecking data contracts...'
    start = time()
    checked = check_contracts(trajs, contracts)
    provenance.extend([contract.configuration().id() for contract in CONTRACTS])
    print '\tChecked:\n\t\t%s' % '\n\t\t'.join(checked)
    print '\tCheck contracts took %.2f seconds' % (time() - start)

    # Compute some extra time-series
    print '\tComputing more time-series...'
    start = time()
    for series_extractor in series_extractors:
        print '\t\t' + series_extractor.configuration().id()
        series_extractor.compute(trajs)
        provenance.append(series_extractor.configuration().id())
    print 'Compute some more series took %.2f seconds' % (time() - start)
    # N.B. we should check more contracts after this, but careful with some missing values that are valid...
    #      that's because we do not support (yet) variable length series
    
    # Save to our extraordinary data format (a pickle)
    with open(cache_file, 'wb') as writer:
        pickle.dump(trajs, writer, protocol=pickle.HIGHEST_PROTOCOL)

    # Save provenance information
    with open(provenance_file, 'w') as writer:
        writer.write('\n'.join(provenance))
        
    print 'Stuff saved to:\n %s\nprovenance:\n  %s' % (cache_file, provenance_file)
# Out:
# 	Loading data from original combine results...
# 	Loaded 16382 trajectories, it took 16.71 seconds
# 	Transforming the trajectories data-set...
# 		ColumnsSelector#keepers=['ax', 'ay', 'az', 'dtheta', 'omega', 'radius', 'ratio', 'rcurve', 'rotation_rate', 'theta', 'trg_x', 'trg_y', 'trg_z', 'velocity', 'vx', 'vy', 'vz', 'x', 'y', 'z']
# 		NumericEnforcer#columns=None
# 		MissingImputer#columns=['rotation_rate', 'trg_x', 'trg_y', 'trg_z', 'ratio']#fpm=ffill#spm=bfill
# 		RowsWithMissingRemover#columns=None
# 	Transformations took 69.13 seconds, there are 16382 trajectories left
# 	Checking data contracts...
# 	Checked:
# 		NoMissingValuesContract#columns=['ax', 'ay', 'az', 'dtheta', 'omega', 'radius', 'ratio', 'rcurve', 'rotation_rate', 'theta', 'trg_x', 'trg_y', 'trg_z', 'velocity', 'vx', 'vy', 'vz', 'x', 'y', 'z']
# 		NoHolesContract#
# 		AllNumericContract#columns=None
# 	Check contracts took 35.45 seconds
# 	Computing more time-series...
# 		PostAttention#postx=-0.15#posty=0.25#ws=20
# 		PostAttention#postx=trg_x#posty=trg_y#ws=20
# 		RollingCorr#min_periods=None#resp=dtheta#stim=rotation_rate#ws=20
# Compute some more series took 1038.90 seconds
# Stuff saved to:
#  /home/santi/data-analysis/strawlab/dcns/20140909/original/munged_data.pkl
# provenance:
#   /home/santi/data-analysis/strawlab/dcns/20140909/original/munged_data-provenance.log

# %%
# %%timeit
# Let's open the cached results
with open(cache_file) as reader_trajs, open(provenance_file) as reader_provenance:
    trajs = pickle.load(reader_trajs)
    provenance = map(str.strip, reader_provenance.readlines())
# Out:
# 1 loops, best of 3: 2.97 s per loop

# %%
'Read %d trajectories' % len(trajs)
# Out:
# 'Read 16382 trajectories'

# %%
print 'This is how we tortured the data until now:\n\t%s' % '\n\t'.join(provenance)
# Out:
# This is how we tortured the data until now:
# 	FreeflightAnalysisFiles#customfilt=None#customfilt_len=None#frames_before=0#idfilt=[]#lenfilt=1.0#rfilt=trim#rfilt_max=0.42#tfilt_after=None#tfilt_before=None#zfilt=trim#zfilt_max=0.9#zfilt_min=0.1
# 	ColumnsSelector#keepers=['ax', 'ay', 'az', 'dtheta', 'omega', 'radius', 'ratio', 'rcurve', 'rotation_rate', 'theta', 'trg_x', 'trg_y', 'trg_z', 'velocity', 'vx', 'vy', 'vz', 'x', 'y', 'z']
# 	NumericEnforcer#columns=None
# 	MissingImputer#columns=['rotation_rate', 'trg_x', 'trg_y', 'trg_z', 'ratio']#fpm=ffill#spm=bfill
# 	RowsWithMissingRemover#columns=None
# 	NoMissingValuesContract#columns=['ax', 'ay', 'az', 'dtheta', 'omega', 'radius', 'ratio', 'rcurve', 'rotation_rate', 'theta', 'trg_x', 'trg_y', 'trg_z', 'velocity', 'vx', 'vy', 'vz', 'x', 'y', 'z']
# 	NoHolesContract#
# 	AllNumericContract#columns=None
# 	PostAttention#postx=-0.15#posty=0.25#ws=20
# 	PostAttention#postx=trg_x#posty=trg_y#ws=20
# 	RollingCorr#min_periods=None#resp=dtheta#stim=rotation_rate#ws=20

# %%
print 'These are the time-series we have for each trajectory: \n\t%s' % '\n\t'.join(trajs[0].df().columns)
# Out:
# These are the time-series we have for each trajectory:
# 	rotation_rate
# 	trg_x
# 	trg_y
# 	trg_z
# 	ratio
# 	x
# 	y
# 	z
# 	vx
# 	vy
# 	vz
# 	velocity
# 	ax
# 	ay
# 	az
# 	theta
# 	dtheta
# 	radius
# 	omega
# 	rcurve
# 	out=dist_to_post#PostAttention#postx=-0.15#posty=0.25#ws=20
# 	out=vel_to_post#PostAttention#postx=-0.15#posty=0.25#ws=20
# 	out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
01:00
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=527#start=756393     2013-12-08 19:25:46.726500+01:00
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=532#start=757174     2013-12-08 19:25:54.578893+01:00
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=537#start=757570     2013-12-08 19:25:58.550130+01:00
# ...                                                                                         ...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13345#start=5647793  2014-06-22 09:44:17.694795+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13347#start=5648153  2014-06-22 09:44:21.293260+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13381#start=5665816  2014-06-22 09:47:18.001029+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13382#start=5667508  2014-06-22 09:47:34.934134+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13404#start=5671868  2014-06-22 09:48:18.539294+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13480#start=5714724  2014-06-22 09:55:27.274194+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13481#start=5715449  2014-06-22 09:55:34.520889+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13498#start=5719617  2014-06-22 09:56:16.219824+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13631#start=5768949  2014-06-22 10:04:29.732185+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13633#start=5769822  2014-06-22 10:04:38.466988+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13635#start=5770488  2014-06-22 10:04:45.127336+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13636#start=5771632  2014-06-22 10:04:56.571011+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13638#start=5771976  2014-06-22 10:05:00.012133+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13640#start=5772144  2014-06-22 10:05:01.697005+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13643#start=5772582  2014-06-22 10:05:06.077178+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13644#start=5772953  2014-06-22 10:05:09.789563+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13657#start=5777892  2014-06-22 10:05:59.197316+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13663#start=5778853  2014-06-22 10:06:08.813127+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13664#start=5779131  2014-06-22 10:06:11.596512+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13795#start=5823577  2014-06-22 10:13:36.227774+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13796#start=5823906  2014-06-22 10:13:39.521240+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13798#start=5824274  2014-06-22 10:13:43.233036+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13802#start=5825047  2014-06-22 10:13:50.931663+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13805#start=5825464  2014-06-22 10:13:55.109039+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13806#start=5825852  2014-06-22 10:13:58.992143+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13949#start=5891313  2014-06-22 10:24:53.857561+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13955#start=5892484  2014-06-22 10:25:05.569518+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13974#start=5898928  2014-06-22 10:26:10.033581+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13977#start=5900391  2014-06-22 10:26:24.674846+02:00
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13988#start=5901423  2014-06-22 10:26:34.999787+02:00
#
#                                                                                                             traj
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=29#start=415243      <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=63#start=424243      <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=68#start=424924      <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=104#start=469307     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=123#start=543142     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=143#start=579602     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=163#start=594945     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=193#start=635106     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=195#start=636284     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=219#start=639243     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=235#start=642194     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=240#start=643645     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=251#start=651998     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=254#start=654576     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=256#start=656467     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=263#start=659749     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=271#start=661044     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=328#start=702080     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=331#start=702538     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=340#start=705525     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=365#start=711249     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=368#start=711581     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=391#start=714128     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=415#start=719260     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=432#start=721844     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=436#start=722824     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=508#start=755096     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=527#start=756393     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=532#start=757174     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=537#start=757570     <flydata.strawlab.trajectories.FreeflightTraje...
# ...                                                                                                          ...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13345#start=5647793  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13347#start=5648153  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13381#start=5665816  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13382#start=5667508  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13404#start=5671868  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13480#start=5714724  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13481#start=5715449  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13498#start=5719617  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13631#start=5768949  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13633#start=5769822  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13635#start=5770488  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13636#start=5771632  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13638#start=5771976  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13640#start=5772144  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13643#start=5772582  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13644#start=5772953  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13657#start=5777892  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13663#start=5778853  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13664#start=5779131  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13795#start=5823577  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13796#start=5823906  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13798#start=5824274  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13802#start=5825047  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13805#start=5825464  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13806#start=5825852  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13949#start=5891313  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13955#start=5892484  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13974#start=5898928  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13977#start=5900391  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13988#start=5901423  <flydata.strawlab.trajectories.FreeflightTraje...
#
# [16382 rows x 7 columns]

# %%
# Let's group trajectories by conflict condition (yes, we could also use groupby)
trajs_on_conflict = trajs_df[trajs_df['condition'] == DCN_CONFLICT_CONDITION]
trajs_on_rotation = trajs_df[trajs_df['condition'] == DCN_ROTATION_CONDITION]
assert len(trajs_df) == len(trajs_on_conflict) + len(trajs_on_rotation)

# %%
# Let's group trajectories by condition and genotype...
print trajs_df.groupby(by=('condition', 'genotype'))['traj'].count()
# Out:
# condition                                                                         genotype
# checkerboard16.png/infinity.svg/+0.3/-10.0/0.1/0.20                               ATOxTNTE         2837
#                                                                                   ATOxTNTin         972
#                                                                                   VT37804xTNTE     1660
#                                                                                   VT37804xTNTin    3128
# checkerboard16.png/infinity.svg/+0.3/-10.0/0.1/0.20/justpost1.osg|-0.15|0.25|0.0  ATOxTNTE         2646
#                                                                                   ATOxTNTin         841
#                                                                                   VT37804xTNTE     1595
#                                                                                   VT37804xTNTin    2703
# Name: traj, dtype: int64

# %%
# ...or by condition and experiment...
print trajs_df.groupby(by=('condition', 'uuid'))['traj'].count()
# Out:
# condition                                                                         uuid
# checkerboard16.png/infinity.svg/+0.3/-10.0/0.1/0.20                               09e0b70a61b811e39cdc6c626d3a008a     174
#                                                                                   0aba1bb0ebc711e2a2706c626d3a008a     372
#                                                                                   2629a5a8078411e4892a6c626d3a008a     243
#                                                                                   44c804fc60ed11e3946c6c626d3a008a      76
#                                                                                   6114907c5d0411e3b3a96c626d3a008a     402
#                                                                                   6ddf495e5dcd11e385a06c626d3a008a    1017
#                                                                                   735483eef8a111e3a0146c626d3a008a     606
#                                                                                   7565cafeefc311e293816c626d3a008a     171
#                                                                                   7c8e05c4f2e511e28d866c626d3a008a     387
#                                                                                   ad0377f0f95d11e38cd26c626d3a008a     841
#                                                                                   ae8425d4084911e4aafb6c626d3a008a     567
#                                                                                   aea9f1e0f7ca11e38cf16c626d3a008a     509
#                                                                                   b006600e5c3511e384a66c626d3a008a     230
#                                                                                   b728144a09dc11e488736c626d3a008a     318
#                                                                                   c7c23d78091711e4bb2a6c626d3a008a     144
#                                                                                   c84256845aa811e393ee6c626d3a008a     378
#                                                                                   d4d3a2fa602411e3a3446c626d3a008a     627
#                                                                                   e03d13240ab511e485096c626d3a008a     308
#                                                                                   e20c67fa5b6911e393ee6c626d3a008a     892
#                                                                                   ef67f4625e9511e398766c626d3a008a     335
# checkerboard16.png/infinity.svg/+0.3/-10.0/0.1/0.20/justpost1.osg|-0.15|0.25|0.0  09e0b70a61b811e39cdc6c626d3a008a     138
#                                                                                   0aba1bb0ebc711e2a2706c626d3a008a     330
#                                                                                   2629a5a8078411e4892a6c626d3a008a     194
#                                                                                   44c804fc60ed11e3946c6c626d3a008a      82
#                                                                                   6114907c5d0411e3b3a96c626d3a008a     302
#                                                                                   6ddf495e5dcd11e385a06c626d3a008a     807
#                                                                                   735483eef8a111e3a0146c626d3a008a     486
#                                                                                   7565cafeefc311e293816c626d3a008a     165
#                                                                                   7c8e05c4f2e511e28d866c626d3a008a     334
#                                                                                   ad0377f0f95d11e38cd26c626d3a008a     786
#                                                                                   ae8425d4084911e4aafb6c626d3a008a     633
#                                                                                   aea9f1e0f7ca11e38cf16c626d3a008a     463
#                                                                                   b006600e5c3511e384a66c626d3a008a     254
#                                                                                   b728144a09dc11e488736c626d3a008a     304
#                                                                                   c7c23d78091711e4bb2a6c626d3a008a     135
#                                                                                   c84256845aa811e393ee6c626d3a008a     383
#                                                                                   d4d3a2fa602411e3a3446c626d3a008a     614
#                                                                                   e03d13240ab511e485096c626d3a008a     288
#                                                                                   e20c67fa5b6911e393ee6c626d3a008a     795
#                                                                                   ef67f4625e9511e398766c626d3a008a     292
# Name: traj, dtype: int64

# %%
# ...or by night/day and genotype...
trajs_df['night'] = trajs_df['traj'].apply(lambda x: x.is_between_hours())
print trajs_df.groupby(by=('night', 'genotype'))['traj'].count()
# Out:
# night  genotype
# False  ATOxTNTE         3055
#        ATOxTNTin        1486
#        VT37804xTNTE     2272
#        VT37804xTNTin    3883
# True   ATOxTNTE         2428
#        ATOxTNTin         327
#        VT37804xTNTE      983
#        VT37804xTNTin    1948
# Name: traj, dtype: int64

# %%
# OK, those counts can actually be misleading, how many trajectories per hour could be better
# e.g. if there are 3 hours of day and 9 of night...
# it should be easy, but left as exercise...

# %%
#
# Now there are a lot of analysis to carry:
#   - look at the plots generated by John for examples (analysislib/plots.py, xxx_analysis.py)
#   - perform more analysis (e.g. time series segmentation, filtering, alignment...)
#   - generate scalar features...
#

# %%
# Lets generate a few features
features = [
    # Total trajectory length (in number of observations)
    Length(),
    # "Attention to rotation stimulus"
    Mean('out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=251#start=651998                                              1.000000
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=254#start=654576                                              0.927711
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=256#start=656467                                              0.940686
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=263#start=659749                                              1.000000
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=271#start=661044                                              0.934269
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=328#start=702080                                              1.000000
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=331#start=702538                                              0.903370
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=340#start=705525                                              0.904787
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=365#start=711249                                              1.000000
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=368#start=711581                                              0.898785
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=391#start=714128                                              0.928557
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=415#start=719260                                              0.884615
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=432#start=721844                                              1.000000
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=436#start=722824                                              0.880879
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=508#start=755096                                              1.000000
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=527#start=756393                                              0.896936
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=532#start=757174                                              1.000000
# uuid=d4d3a2fa602411e3a3446c626d3a008a#oid=537#start=757570                                              0.839474
# ...                                                                                                          ...
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13345#start=5647793                                           0.940000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13347#start=5648153                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13381#start=5665816                                           0.912855
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13382#start=5667508                                           0.747720
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13404#start=5671868                                           0.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13480#start=5714724                                           0.891729
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13481#start=5715449                                           0.903433
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13498#start=5719617                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13631#start=5768949                                           0.975400
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13633#start=5769822                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13635#start=5770488                                           0.978782
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13636#start=5771632                                           0.760331
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13638#start=5771976                                           0.527778
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13640#start=5772144                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13643#start=5772582                                           0.938272
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13644#start=5772953                                           0.968571
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13657#start=5777892                                           0.985342
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13663#start=5778853                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13664#start=5779131                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13795#start=5823577                                           0.821561
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13796#start=5823906                                           0.707165
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13798#start=5824274                                           0.805085
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13802#start=5825047                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13805#start=5825464                                           0.759146
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13806#start=5825852                                           0.905660
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13949#start=5891313                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13955#start=5892484                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13974#start=5898928                                           1.000000
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13977#start=5900391                                           0.968619
# uuid=ad0377f0f95d11e38cd26c626d3a008a#oid=13988#start=5901423                                           0.929952
#
# [16382 rows x 12 columns]

# %%
# With these awfully named features
print '\n'.join(df_features.columns)
# Out:
# Length#column=x
# Mean#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Std#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Skew#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Kurtosis#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Mean#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# Std#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# Skew#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# Kurtosis#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# TimeInCircularRegion#center=(-0.15, 0.25)#radius=0.1
# TimeInCircularRegion#center=(-0.15, 0.25)#radius=0.25
# TimeInCircularRegion#center=(-0.15, 0.25)#radius=0.5

# %%
# let's just use "long" trajectories
df_features = df_features[df_features['Length#column=x'] >= 400]
# and explore a bit their destribution, comparing by genotype (TODO: extend to other groupings, like DCNImpaired vs Not, post vs not...)
for fname in df_features.columns:
    print 'Plotting:', fname
    plt.figure(figsize=(16, 12), dpi=200)
    sb.violinplot(df_features[fname], trajs_df['genotype'], cut=20)
    plt.title(fname)
    plt.savefig(op.join(op.expanduser('~'), '%s.png' % fname.replace('#', '__')))
    plt.show()
# Out:
# Plotting: Length#column=x
# Plotting: Mean#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Plotting: Std#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Plotting: Skew#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Plotting: Kurtosis#column=out=fly_post_cosine#PostAttention#postx=trg_x#posty=trg_y#ws=20
# Plotting: Mean#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# Plotting: Std#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# Plotting: Skew#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# Plotting: Kurtosis#column=out=fly_post_cosine#PostAttention#postx=-0.15#posty=0.25#ws=20
# Plotting: TimeInCircularRegion#center=(-0.15, 0.25)#radius=0.1
# Plotting: TimeInCircularRegion#center=(-0.15, 0.25)#radius=0.25
# Plotting: TimeInCircularRegion#center=(-0.15, 0.25)#radius=0.5
