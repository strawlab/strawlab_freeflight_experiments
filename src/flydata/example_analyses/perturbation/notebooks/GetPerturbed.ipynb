# %%
from time import time

import matplotlib.pyplot as plt
import numpy as np

from flydata.strawlab.experiments import load_freeflight_trajectories
from flydata.strawlab.trajectories import FreeflightTrajectory
from flydata.strawlab.transformers import MissingImputer, RowsWithMissingRemover
from flydata.strawlab.contracts import NoMissingValuesContract

# %%
UUIDS = (
    '83a8ba40433711e4a4186c626d3a008a',  # This is last exp in flycave
    '8feffabc288311e4a31810bf48d76973',  # This is Katja perturbations-working experiment, in flycube1
    'c37d5432433711e4b998bcee7bdac44a',  # This is Katja perturbations-not-working experiment, in flycube10
                                         # we suspect that, due to the size of the loop,
                                         # no fly triggered the perturbation start condition.
)

# %%
#######################
# Get the data in
#######################

#
# We can get that data in many ways, all of them useful and valid:
#   - using combine passing the many uuids, maybe asking for using the caches
#   - reading directly the pickles from /mnt/strawscience/data/plots
#   - using the flydata package, if you are already happy with your combine parameters
#     (this aims to make accessing freeflight trajectories easier and, at the moment
#     expects pickles from "combine" data)
#

# Load all the trajectories data / metadata
start = time()
trajs = load_freeflight_trajectories(UUIDS)
print 'There are %d trajectories and it took %.2f seconds to load them' % (len(trajs), time() - start)
# Out:
# There are 1064 trajectories and it took 2.20 seconds to load them

# %%
# Keep only trajectories from perturbation trials
trajs = [traj for traj in trajs if 'multitone' in traj.condition()]
print 'There are %d perturbation trials' % len(trajs)
# Out:
# There are 298 perturbation trials

# %%
# Let's see a bit what is in store
trajs_df = FreeflightTrajectory.to_pandas(trajs)
print trajs_df.groupby(('genotype', 'condition'))['traj'].count()
# Out:
# genotype               condition
# CS                     checkerboard16.png/infinity07.svg/+0.3/-5.0/0.1/0.20/multitone_rotation_rate|rudinshapiro|0.7|2|1|5||0.4|0.46|0.56|0.96|1.0|0.0|0.06    140
# VT58487 x Kir2.1       checkerboard16.png/infinity.svg/+0.3/-10.0/0.1/0.20/multitone_rotation_rate|rudinshapiro|1.8|3|1|5||0.4|0.46|0.56|0.96|1.0|0.0|0.06      32
#                        checkerboard16.png/infinity.svg/+0.3/-10.0/0.1/0.20/multitone_z|rudinshapiro|0.1|3|1|5||0.4|0.46|0.56|0.96|1.0|0.0|0.06                  43
# nsyb-GAL4 x Ast KH006  checkerboard16.png/infinity05.svg/+0.3/-5.0/0.1/0.20/multitone_rotation_rate|rudinshapiro|0.7|2|1|5||0.4|0.46|0.56|0.96|1.0|0.0|0.06     83
# Name: traj, dtype: int64

# %%
trajs_df
# Out:
#                                                                                            uuid  \
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=366#start=517628     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=373#start=522772     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=494#start=622040     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=499#start=627130     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=507#start=627322     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=634#start=698257     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=649#start=702625     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=655#start=704829     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=661#start=709958     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=745#start=791305     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=746#start=791856     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=748#start=792429     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=788#start=809100     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=792#start=809655     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=914#start=893564     83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1092#start=1054944   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1125#start=1071219   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1228#start=1143986   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1284#start=1155467   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1407#start=1245294   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1501#start=1328079   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1519#start=1333063   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=2812#start=1868805   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=2837#start=1880777   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=3258#start=2326857   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=3431#start=2688988   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=4251#start=2868906   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=5056#start=3415384   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=5142#start=3771437   83a8ba40433711e4a4186c626d3a008a
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=
02:00
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12704#start=5849990  2014-09-24 09:55:07.461721+02:00
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12705#start=5850186  2014-09-24 09:55:09.408874+02:00
#
#                                                                                                             traj
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=366#start=517628     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=373#start=522772     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=494#start=622040     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=499#start=627130     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=507#start=627322     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=634#start=698257     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=649#start=702625     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=655#start=704829     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=661#start=709958     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=745#start=791305     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=746#start=791856     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=748#start=792429     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=788#start=809100     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=792#start=809655     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=914#start=893564     <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1092#start=1054944   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1125#start=1071219   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1228#start=1143986   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1284#start=1155467   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1407#start=1245294   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1501#start=1328079   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1519#start=1333063   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=2812#start=1868805   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=2837#start=1880777   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=3258#start=2326857   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=3431#start=2688988   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=4251#start=2868906   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=5056#start=3415384   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=5142#start=3771437   <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=5481#start=4473823   <flydata.strawlab.trajectories.FreeflightTraje...
# ...                                                                                                          ...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11451#start=5469203  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11477#start=5478615  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11520#start=5490512  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11553#start=5504856  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11576#start=5516293  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11627#start=5538442  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11729#start=5574389  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11732#start=5575162  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11828#start=5598727  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11943#start=5646915  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11987#start=5660633  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=11989#start=5661098  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12021#start=5670564  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12063#start=5684893  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12089#start=5695989  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12122#start=5706403  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12131#start=5709078  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12168#start=5720375  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12169#start=5720491  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12170#start=5720686  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12306#start=5752511  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12385#start=5779033  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12391#start=5780515  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12462#start=5802135  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12590#start=5826487  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12596#start=5827393  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12659#start=5839453  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12660#start=5839722  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12704#start=5849990  <flydata.strawlab.trajectories.FreeflightTraje...
# uuid=c37d5432433711e4b998bcee7bdac44a#oid=12705#start=5850186  <flydata.strawlab.trajectories.FreeflightTraje...
#
# [298 rows x 7 columns]

# %%
#######################
# Simple perturbation exploration
#######################
#
# Here goes, my first time looking into perturbation experiments
# One can also look in scripts/perturbation-analysis.py/plot_perturbation_traces
#   or scripts/sid-analysis.py  in latest sid-analysis branch from John
#   or src/strawlab_freeflight_experiments/perturb.py
# and probably other places... only John knows what is correct atm
#
#######################

def perturbation_has_been_triggered(traj):
    """Returns True iff a trajectory contains perturbation information and the perturbation was actually triggered."""
    return 'perturb_progress' in traj.df().columns and (traj.df()['perturb_progress'] > 0).any()

# we can add a column to our df...
trajs_df['has_perturbation'] = trajs_df['traj'].apply(perturbation_has_been_triggered)
print trajs_df.groupby(('has_perturbation', 'uuid'))['traj'].count()
# so indeed, the perturbation was not triggered in experiment c37d5432433711e4b998bcee7bdac44a
# Out:
# has_perturbation  uuid
# False             83a8ba40433711e4a4186c626d3a008a     50
#                   8feffabc288311e4a31810bf48d76973     46
#                   c37d5432433711e4b998bcee7bdac44a    140
# True              83a8ba40433711e4a4186c626d3a008a     25
#                   8feffabc288311e4a31810bf48d76973     37
# Name: traj, dtype: int64

# %%
# we can also just work with these trajectories from now on...
trajs = filter(perturbation_has_been_triggered, trajs)
trajs_df = FreeflightTrajectory.to_pandas(trajs)  # Update our convenient df

# %%
# We are interested in perturb_progress.
#   its values are -1 if no perturbation is in place, >=0 if perturbation is in place
#   it also has NaNs, let's get rid of them...
trajs = MissingImputer(columns=('perturb_progress',)).fit_transform(trajs)
# Out:
# WARNING: numba is not installed, slow filling will make you impatient

# %%
# Make sure it has worked...
if not NoMissingValuesContract(columns=('perturb_progress',)).check(trajs):
    print 'There are still trajectories with missing values, indicating constant missing series'  # FIXME: catch this
    print 'We remove them...'
    trajs = RowsWithMissingRemover(columns=('perturb_progress',)).fit_transform(trajs)
    trajs_df = FreeflightTrajectory.to_pandas(trajs)  # Update our convenient df
    print 'Now there are %d trajectories' % len(trajs)

# %%
# We can see when the perturbations happened...
def perturbation_limits(traj):
    """Returns frame_start, frame_end for when the perturbation trial happened, None if it did not happen."""
    when_perturbation_happened = np.where(traj.df()['perturb_progress'] > -1)[0]
    if 0 == len(when_perturbation_happened):
        return None
    return when_perturbation_happened[0], when_perturbation_happened[-1]

# %%
# ...putting them in a our pandas dataframe
trajs_df['perturbation_limits'] = trajs_df['traj'].apply(perturbation_limits)
trajs_df['perturbation_limits']
# Out:
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=494#start=622040       (668, 966)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=634#start=698257       (518, 749)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=655#start=704829       (553, 853)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=661#start=709958          (0, 10)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=748#start=792429      (846, 1040)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1125#start=1071219     (273, 410)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=1284#start=1155467     (467, 602)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=5481#start=4473823     (551, 846)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=134#start=207733       (463, 619)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=167#start=291044       (612, 856)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=296#start=477074       (525, 788)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=406#start=563474        (0, 1009)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=412#start=565496      (999, 1157)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=547#start=653579       (476, 771)
# uuid=83a8ba40433711e4a4186c626d3a008a#oid=548#start=655649       (437, 732)
# ...
# uuid=8feffabc288311e4a31810bf48d76973#oid=5834#start=4769285        (0, 0)
# uuid=8feffabc288311e4a31810bf48d76973#oid=5967#start=4882489    (209, 405)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6367#start=5116268    (156, 253)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6368#start=5116564      (0, 155)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6397#start=5125293    (432, 516)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6605#start=5246316        (0, 0)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6607#start=5246618    (220, 253)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6609#start=5246922       (0, 10)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6776#start=5344609    (141, 152)
# uuid=8feffabc288311e4a31810bf48d76973#oid=6803#start=5361366    (129, 326)
# uuid=8feffabc288311e4a31810bf48d76973#oid=7033#start=5460730    (146, 342)
# uuid=8feffabc288311e4a31810bf48d76973#oid=7043#start=5466926    (212, 255)
# uuid=8feffabc288311e4a31810bf48d76973#oid=7045#start=5467232       (0, 10)
# uuid=8feffabc288311e4a31810bf48d76973#oid=7530#start=5704296    (259, 455)
# uuid=8feffabc288311e4a31810bf48d76973#oid=7562#start=5718493     (83, 205)
# Name: perturbation_limits, Length: 62, dtype: object

# %%
# or... making the basicmost plot possible, per trajectory...
def plot_perturb_limits(traj):
    start, end = perturbation_limits(traj)
    plt.figure()
    plt.plot(traj.df()['x'], color='b', label='x')
    plt.plot(traj.df()['y'], color='g', label='y')
    plt.axvline(x=start, color='k')
    plt.axvline(x=end, color='k')
    plt.title(traj.id_string())
    plt.legend()    
plot_perturb_limits(trajs[0])
